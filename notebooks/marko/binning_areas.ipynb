# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../raw_data/Crimes.csv")

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
data=df[['Date', 'Community Area', 'Year']]

# %%
ca_df=data[data.Year > 2002].set_index("Date").groupby("Community Area").count().sort_values("Year")

# %%
ca_df.plot(kind="bar")
# Out:
# <Axes: xlabel='Community Area'>

# %%
ca_df.rename(columns= { "Year" : "Crime Count"}, inplace=True)
ca_df.drop(0, inplace=True)

# %%
#ca_df[(ca_df['Crime Count'] >= 100000) & (ca_df['Crime Count'] < 200000)]

# %%
area_bins=[[25]]

for i in range(3):
    area_bins.append(list( ca_df[ ( ca_df['Crime Count'] < 100000*(3-i) ) & ( ca_df['Crime Count'] >= 100000*(2-i) )  ].index) )

len(area_bins)
# Out:
# 4
