# %% [markdown]
# # Valentina's Notebook: Data Prep

# %% [markdown]
# ### Findings and ToDos
#
# - We have around 600 tsd missings values in Comminities, but Lon and Lat Data are there ->
#   backtrack community data UPD: these are only years 2001 and 2002
# - MB do a dataviz for the districts vs beats vs communities?

# %%
import pandas as pd
from pandas_gbq import read_gbq

from google.cloud import bigquery
from google.oauth2 import service_account

# %%
credentials = service_account.Credentials.from_service_account_file("/Users/valentinahilfiger/Documents/LW_folder/wagon-bootcamp-428814-452deb1a483b.json")

client = bigquery.Client('wagon-bootcamp-428814', credentials)
# query = client.query(
# "SELECT * FROM `wagon-bootcamp-428814.chicago_crime.chicago_crime_tab` LIMIT 100"
    
# )

# %%
query = "SELECT * FROM `wagon-bootcamp-428814.chicago_crime.chicago_crime_tab` LIMIT 100"
df = read_gbq(query, credentials = credentials, project_id = PROJECT_ID)
df
# Out:
#                   Date       ID Case Number                     Block  IUCR  \
# 0  2009-03-30 11:00:00  6835247    HR243390       015XX W CARROLL AVE  0810
# 1  2009-03-30 11:00:00  6835354    HR243558   019XX N NEW ENGLAND AVE  2825
# 2  2009-03-30 11:00:00  6839566    HR246471      009XX W MARQUETTE RD  0890
# 3  2009-03-30 11:00:00  6838951    HR242605           039XX W 79TH ST  0460
# 4  2009-03-30 11:00:00  6873197    HR273384        049XX S PULASKI RD  0910
# ..                 ...      ...         ...                       ...   ...
# 95 2009-03-30 12:20:00  6835182    HR242685  027XX N NARRAGANSETT AVE  0460
# 96 2009-03-30 12:25:00  6834703    HR242733           012XX W 51ST ST  2024
# 97 2009-03-30 12:26:00  6835077    HR242724           011XX W 59TH ST  051A
# 98 2009-03-30 12:28:00  6844454    HR251236       060XX N SHERIDAN RD  0890
# 99 2009-03-30 12:30:00  6835901    HR242717        114XX S FOREST AVE  0430
#
#            Primary Type                    Description  \
# 0                 THEFT                      OVER $500
# 1         OTHER OFFENSE        HARASSMENT BY TELEPHONE
# 2                 THEFT                  FROM BUILDING
# 3               BATTERY                         SIMPLE
# 4   MOTOR VEHICLE THEFT                     AUTOMOBILE
# ..                  ...                            ...
# 95              BATTERY                         SIMPLE
# 96            NARCOTICS            POSS: HEROIN(WHITE)
# 97              ASSAULT            AGGRAVATED: HANDGUN
# 98                THEFT                  FROM BUILDING
# 99              BATTERY  AGGRAVATED: OTHER DANG WEAPON
#
#               Location Description Arrest Domestic  ... Ward Community Area  \
# 0                           STREET  false    false  ...   27             28
# 1                        RESIDENCE  false    false  ...   36             25
# 2                        APARTMENT  false    false  ...   17             68
# 3         SCHOOL, PUBLIC, BUILDING  false    false  ...   18             70
# 4                            OTHER  false    false  ...   14             57
# ..                             ...    ...      ...  ...  ...            ...
# 95  PARKING LOT/GARAGE(NON.RESID.)  false    false  ...   36             19
# 96                           ALLEY   true    false  ...   16             61
# 97                      RESTAURANT  false    false  ...   16             68
# 98         RESIDENCE PORCH/HALLWAY  false    false  ...   48             77
# 99                          STREET  false     true  ...    9             49
#
#     FBI Code       X Coordinate       Y Coordinate  Year  \
# 0         06  1166186.000000000  1902271.000000000  2009
# 1         26  1130119.000000000  1912074.000000000  2009
# 2         06  1171014.000000000  1860402.000000000  2009
# 3        08B  1151370.000000000  1851889.000000000  2009
# 4         07  1150534.000000000  1871486.000000000  2009
# ..       ...                ...                ...   ...
# 95       08B  1133279.000000000  1917422.000000000  2009
# 96        18  1168711.000000000  1870956.000000000  2009
# 97       04A  1169526.000000000  1865667.000000000  2009
# 98        06  1168540.000000000  1940169.000000000  2009
# 99       04B  1180288.000000000  1829147.000000000  2009
#
#                 Updated On      Latitude      Longitude  \
# 0   02/28/2018 03:56:25 PM  41.887411478  -87.665168378
# 1   02/10/2018 03:50:01 PM  41.915006497  -87.797394243
# 2   02/28/2018 03:56:25 PM  41.772414512  -87.648664033
# 3   02/28/2018 03:56:25 PM  41.749460005  -87.720896120
# 4   02/28/2018 03:56:25 PM  41.803253595  -87.723450320
# ..                     ...           ...            ...
# 95  02/28/2018 03:56:25 PM  41.929627277  -87.785659069
# 96  02/28/2018 03:56:25 PM  41.801425943  -87.656801748
# 97  02/28/2018 03:56:25 PM  41.786894685  -87.653966132
# 98  02/28/2018 03:56:25 PM  41.991354683  -87.655423248
# 99  09/07/2021 03:41:02 PM  41.686439349  -87.615623747
#
#                          Location
# 0   (41.887411478, -87.665168378)
# 1   (41.915006497, -87.797394243)
# 2   (41.772414512, -87.648664033)
# 3    (41.749460005, -87.72089612)
# 4    (41.803253595, -87.72345032)
# ..                            ...
# 95  (41.929627277, -87.785659069)
# 96  (41.801425943, -87.656801748)
# 97  (41.786894685, -87.653966132)
# 98  (41.991354683, -87.655423248)
# 99  (41.686439349, -87.615623747)
#
# [100 rows x 22 columns]

# %%
district_query = """
SELECT `Community Area`, COUNT(*) as `Count`
FROM `wagon-bootcamp-428814.chicago_crime.chicago_crime_tab`
GROUP BY `Community Area`
ORDER BY `Count` DESC
"""
stats_communities = read_gbq(district_query, credentials = credentials, project_id = PROJECT_ID)
stats_communities.head(11)
# Out:
# /Users/valentinahilfiger/.pyenv/versions/3.10.6/envs/lw-crime/lib/python3.10/site-packages/google/cloud/bigquery/table.py:2379: UserWarning: A progress bar was requested, but there was an error loading the tqdm library. Please install tqdm to use the progress bar functionality.
#   record_batch = self.to_arrow(
#    Community Area   Count
# 0            None  613453
# 1              25  465316
# 2               8  267887
# 3              43  247842
# 4              23  233537
# 5              28  231062
# 6              24  220750
# 7              29  219150
# 8              71  212253
# 9              67  211380
# 10             49  198512

# %% [markdown]
# ## Spatial Data
